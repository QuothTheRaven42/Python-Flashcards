# %%
import csv
import random

num_questions = 10

def reading_csv():
    with open('flashcards.csv') as csvfile:
        reader = csv.DictReader(csvfile)
        rows = list(reader)
        random.shuffle(rows)

        topics = {row['category'] for row in rows}
        print("Choose a topic (match case):")

        for topic in topics:
            print("• " + topic)
        print("• all\n")
        choice = input("").strip()

        excluded_rows = []
        filtered_rows = rows

        if choice != "all":
            excluded_rows = [row for row in rows if row['category'] != choice]
            filtered_rows = [row for row in rows if row['category'] == choice]

        session_questions = filtered_rows[:num_questions]
        remainder = filtered_rows[num_questions:]

        for row in session_questions:
            print(f"""{row['question']}
    (a): {row['a']}
    (b): {row['b']}
    (c): {row['c']}
    (d): {row['d']}""")

            correct = 0
            while True:
                answer = input("What is your answer? ").strip().lower()
                if answer not in ["a", "b", "c", "d"]:
                    print("Invalid Input")
                elif answer == row['answer']:
                    print("Correct!")
                    correct += 1
                    print("------------------------------------")
                    break
                else:
                    print(f"Wrong! The correct answer was {row['answer']}.")
                    row["times_missed"] = int(row['times_missed']) + 1
                    print("------------------------------------")
                    break

        print(f"Score: {round((correct / len(session_questions) * 100))}%")

        fieldnames = reader.fieldnames
        with open('flashcards.csv', 'w', newline='') as csvfile:
            rows = session_questions + remainder
            writer = csv.DictWriter(csvfile, fieldnames)
            writer.writeheader()
            writer.writerows(rows + excluded_rows)

reading_csv()
# Out:
# Choose a topic (match case):
# • OOP
# • error_handling
# • file_io
# • functions
# • dictionaries
# • operators
# • lists
# • data_structures
# • generators
# • all
#
# What problem does MRO solve?
#     (a): Memory allocation in large classes
#     (b): Naming conflicts between modules
#     (c): Circular imports
#     (d): The order of method resolution in multiple inheritance
# Correct!
# ------------------------------------
# What is a list comprehension?
#     (a): A way to sort a list
#     (b): A method to copy a list
#     (c): A way to merge two lists
#     (d): A concise single-line syntax to build a list using a loop
# Correct!
# ------------------------------------
# What does dict.get('key') return if the key doesn't exist?
#     (a): It raises a KeyError
#     (b): It returns 0
#     (c): It returns None by default
#     (d): It returns an empty string
# Correct!
# ------------------------------------
# What does 'yield' do inside a function?
#     (a): Raises an exception
#     (b): Returns a value and exits the function
#     (c): Skips the current iteration
#     (d): Suspends the function and returns a value, resuming on the next call
# Correct!
# ------------------------------------
# What is the difference between list.append() and list.extend()?
#     (a): They are identical
#     (b): append() adds each element individually; extend() nests the input
#     (c): extend() only works with tuples
#     (d): append() adds the input as one element; extend() unpacks it and adds each element individually
# Wrong! The correct answer was d.
# ------------------------------------
# What bracket type do tuples use?
#     (a): Square brackets []
#     (b): Curly braces {}
#     (c): Angle brackets <>
#     (d): Parentheses ()
# Wrong! The correct answer was d.
# ------------------------------------
# Which method type receives 'cls' as its first parameter?
#     (a): Instance method
#     (b): Static method
#     (c): Class method
#     (d): Property method
# Correct!
# ------------------------------------
# Which method type receives neither 'self' nor 'cls' as a parameter?
#     (a): Instance method
#     (b): Class method
#     (c): Abstract method
#     (d): Static method
# Correct!
# ------------------------------------
# What is the difference between 'is' and '=='?
#     (a): 'is' only works on integers
#     (b): '==' checks identity; 'is' checks value
#     (c): They are identical
#     (d): 'is' checks identity (memory location); '==' checks equality of value
# Correct!
# ------------------------------------
# What is the purpose of __init__ in a class?
#     (a): To delete an instance
#     (b): To define class-level variables only
#     (c): To copy a class
#     (d): To initialize a new instance and set its instance attributes
# Correct!
# ------------------------------------
# Score: 80%
